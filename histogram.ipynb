# %%
import pandas as pd

# Data
data = {
    'Country': ['Denmark', 'Hong Kong', 'China', 'Uruguay', 'Australia', 'United States', 'Netherlands', 'Switzerland', 'Canada', 'Vanuatu', 'Ireland', 'France', 'Italy', 'United Kingdom', 'Spain', 'Vatican City', 'Belgium', 'Austria', 'Germany', 'Greece', 'Mexico'],
    'AveragePrice': [618.6093294460642, 506.2485242030697, 261.6875, 237.0, 158.23370990871254, 146.86845102505694, 139.04409070810436, 116.22762762762763, 112.95026375282592, 110.0, 98.05898653998416, 92.57525974819704, 91.24657534246575, 87.18530779868415, 82.7431915372496, 70.0, 66.69785437917693, 64.98334732717605, 57.50764290301863, 53.93151750972763, 25.0]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display DataFrame
print(df)
# Out:
#            Country  AveragePrice
# 0          Denmark    618.609329
# 1        Hong Kong    506.248524
# 2            China    261.687500
# 3          Uruguay    237.000000
# 4        Australia    158.233710
# 5    United States    146.868451
# 6      Netherlands    139.044091
# 7      Switzerland    116.227628
# 8           Canada    112.950264
# 9          Vanuatu    110.000000
# 10         Ireland     98.058987
# 11          France     92.575260
# 12           Italy     91.246575
# 13  United Kingdom     87.185308
# 14           Spain     82.743192
# 15    Vatican City     70.000000
# 16         Belgium     66.697854
# 17         Austria     64.983347
# 18         Germany     57.507643
# 19          Greece     53.931518
# 20          Mexico     25.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Country'], df['AveragePrice'], color='skyblue')
plt.title('Average Price by Country')
plt.xlabel('Country')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
data_property_type = {
    'Property type': ['Timeshare', 'Island', 'Boat', 'Lighthouse', 'Villa', 'Castle', 'Igloo', 'Townhouse', 'House', 'Condominium',
                      'Chalet', 'Loft', 'Vacation home', 'Entire Floor', 'Serviced apartment', 'Treehouse', 'Boutique hotel', 'Cave',
                      'Bungalow', 'Cabin', 'Apartment', 'In-law', 'Other', 'Yurt', 'Guest suite', 'Guesthouse', 'Train', 'Nature lodge',
                      'Earth House', 'Camper/RV', 'Hut', 'Tipi', 'Dorm', 'Bed & Breakfast', 'Heritage hotel (India)', 'Plane', 'Tent',
                      'Hostel', 'Parking Space', 'Casa particular', 'Ryokan (Japan)'],
    'AveragePrice': [256.56906077348066, 250.8, 190.99027777777778, 173.8, 171.48753462603878, 157.4, 153.66666666666666, 149.6834228702993,
                     149.57590701463442, 148.55095249024558, 147.37037037037038, 142.92466561762393, 134.86567164179104, 134.5, 128.31800766283524,
                     124.91379310344827, 123.71678321678321, 122.0, 120.56608933454876, 119.69308176100628, 118.6792208599927, 117.68707482993197,
                     114.57342922028766, 113.24, 110.86274509803921, 108.96352785145889, 106.71428571428571, 106.22222222222223, 104.29729729729729,
                     99.15277777777777, 99.04545454545455, 97.06666666666666, 86.64285714285714, 82.94631324004305, 79.0, 65.0, 63.47674418604651,
                     56.76851851851852, 50.0, 50.0, 35.0]
}

# Create DataFrame
df_property_type = pd.DataFrame(data_property_type)

# Display DataFrame
print(df_property_type)
# Out:
#              Property type  AveragePrice
# 0                Timeshare    256.569061
# 1                   Island    250.800000
# 2                     Boat    190.990278
# 3               Lighthouse    173.800000
# 4                    Villa    171.487535
# 5                   Castle    157.400000
# 6                    Igloo    153.666667
# 7                Townhouse    149.683423
# 8                    House    149.575907
# 9              Condominium    148.550952
# 10                  Chalet    147.370370
# 11                    Loft    142.924666
# 12           Vacation home    134.865672
# 13            Entire Floor    134.500000
# 14      Serviced apartment    128.318008
# 15               Treehouse    124.913793
# 16          Boutique hotel    123.716783
# 17                    Cave    122.000000
# 18                Bungalow    120.566089
# 19                   Cabin    119.693082
# 20               Apartment    118.679221
# 21                  In-law    117.687075
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_property_type['Property type'], data_property_type['AveragePrice'], color='skyblue')
plt.title('Average Price by Property type')
plt.xlabel('Property type')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Data
data_room_type = {
    'Room type': ['Entire home/apt', 'Private room', 'Shared room'],
    'AveragePrice': [155.29473603503064, 72.4952483836382, 52.15002373793322]
}

# Create DataFrame
df_room_type = pd.DataFrame(data_room_type)

# Display DataFrame
print(df_room_type)
# Out:
#          Room type  AveragePrice
# 0  Entire home/apt    155.294736
# 1     Private room     72.495248
# 2      Shared room     52.150024

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_room_type['Room type'], data_room_type['AveragePrice'], color='skyblue')
plt.title('Average Price by data_room_type')
plt.xlabel('data_room_type')
plt.ylabel('Average Price')
plt.xticks(rotation=0)  
plt.tight_layout()
plt.show()

# %%
# Data
data_accommodates = {
    'Accommodates': [20, 18, 14, 12, 15, 16, 17, 13, 10, 11, 8, 9, 7, 6, 5, 4, 3, 2, 1],
    'AveragePrice': [750.0, 575.0, 375.0518018018018, 357.73204419889504, 354.16279069767444, 353.40532825880115, 350.0, 341.5408163265306,
                     316.8109393579073, 298.7241379310345, 269.22472810532344, 263.7098121085595, 227.57099879663056, 201.29643779791144,
                     166.64051457597174, 140.04960301759382, 115.91773836541425, 92.17363243270904, 61.42554237169136]
}

# Create DataFrame
df_accommodates = pd.DataFrame(data_accommodates)

# Display DataFrame
print(df_accommodates)
# Out:
#     Accommodates  AveragePrice
# 0             20    750.000000
# 1             18    575.000000
# 2             14    375.051802
# 3             12    357.732044
# 4             15    354.162791
# 5             16    353.405328
# 6             17    350.000000
# 7             13    341.540816
# 8             10    316.810939
# 9             11    298.724138
# 10             8    269.224728
# 11             9    263.709812
# 12             7    227.570999
# 13             6    201.296438
# 14             5    166.640515
# 15             4    140.049603
# 16             3    115.917738
# 17             2     92.173632
# 18             1     61.425542

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_accommodates['Accommodates'], data_accommodates['AveragePrice'], color='skyblue')
plt.title('Average Price by Accommodates')
plt.xlabel('Accommodates')
plt.ylabel('Average Price')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Data
data_bathrooms = {
    'Bathrooms': [4.5, 3.5, 5.0, 4.0, 6.0, 5.5, 7.0, 3.0, 2.5, 6.5, 2.0, 7.5, 8.0, 1.5, 1.0, 0.0, 0.5, 15.5],
    'AveragePrice': [421.75522388059704, 375.7961099932931, 314.26196473551636, 312.8798151001541, 306.375, 302.99212598425197, 290.07954545454544,
                     285.6865698729583, 265.0001631853786, 222.0, 182.13770476099242, 159.0, 130.45549738219896, 122.67364183110493, 108.72551382897741,
                     75.29194630872483, 73.50903294367694, 0.0]
}

# Create DataFrame
df_bathrooms = pd.DataFrame(data_bathrooms)

# Display DataFrame
print(df_bathrooms)
# Out:
#     Bathrooms  AveragePrice
# 0         4.5    421.755224
# 1         3.5    375.796110
# 2         5.0    314.261965
# 3         4.0    312.879815
# 4         6.0    306.375000
# 5         5.5    302.992126
# 6         7.0    290.079545
# 7         3.0    285.686570
# 8         2.5    265.000163
# 9         6.5    222.000000
# 10        2.0    182.137705
# 11        7.5    159.000000
# 12        8.0    130.455497
# 13        1.5    122.673642
# 14        1.0    108.725514
# 15        0.0     75.291946
# 16        0.5     73.509033
# 17       15.5      0.000000

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_bathrooms['Bathrooms'], data_bathrooms['AveragePrice'], color='skyblue')
plt.title('Average Price by Bathrooms')
plt.xlabel('Bathrooms')
plt.ylabel('Average Price')
plt.tight_layout()
plt.show()

# %%
# Data
data_bedrooms = {
    'Bedrooms': [8, 9, 7, 6, 5, 4, 10, 3, 2, 1, 0, 14],
    'AveragePrice': [450.85135135135135, 443.10526315789474, 404.2742857142857, 388.2959183673469, 368.65534718702486, 314.70910232266164,
                     314.0886075949367, 233.0258627560373, 167.87636266555924, 96.21764686181258, 89.18132895516942, 0.0]
}

# Create DataFrame
df_bedrooms = pd.DataFrame(data_bedrooms)

# Display DataFrame
print(df_bedrooms)
# Out:
#     Bedrooms  AveragePrice
# 0          8    450.851351
# 1          9    443.105263
# 2          7    404.274286
# 3          6    388.295918
# 4          5    368.655347
# 5          4    314.709102
# 6         10    314.088608
# 7          3    233.025863
# 8          2    167.876363
# 9          1     96.217647
# 10         0     89.181329
# 11        14      0.000000

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_bedrooms['Bedrooms'], data_bedrooms['AveragePrice'], color='skyblue')
plt.title('Average Price by Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Average Price')
plt.tight_layout()
plt.show()

# %%
# Data
data_price_range = {
    'Price_Range': ['1-100', '101-200', '201-300', '301-400', '401-500', '501-600', '601-700', '701-800', '801-900', '901-999'],
    'Count': [300381, 130275, 35169, 14706, 9881, 5661, 4666, 4106, 2986, 2319]
}

# Create DataFrame
df_price_range = pd.DataFrame(data_price_range)

# Display DataFrame
print(df_price_range)
# Out:
#   Price_Range   Count
# 0       1-100  300381
# 1     101-200  130275
# 2     201-300   35169
# 3     301-400   14706
# 4     401-500    9881
# 5     501-600    5661
# 6     601-700    4666
# 7     701-800    4106
# 8     801-900    2986
# 9     901-999    2319

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_price_range['Price_Range'], data_price_range['Count'], color='skyblue')
plt.title('Price_Range by Count')
plt.xlabel('Price_Range')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Data
data_country_counts = {
    'Country': ['United States', 'United Kingdom', 'France', 'Spain', 'Australia', 'Canada', 'Italy', 'Germany', 'Netherlands', 'Denmark', 'Austria', 'Belgium', 'Ireland', 'Hong Kong', 'Greece', 'Switzerland', 'China', 'Vatican City', 'Mexico', 'Cuba', 'Vanuatu', 'Uruguay'],
    'Count': [141383, 63928, 56198, 50392, 40107, 33723, 33006, 20477, 18503, 16531, 9141, 7392, 6706, 5281, 5107, 2358, 50, 2, 2, 1, 1, 1]
}

# Create DataFrame
df_country_counts = pd.DataFrame(data_country_counts)

# Display DataFrame
print(df_country_counts)
# Out:
#            Country   Count
# 0    United States  141383
# 1   United Kingdom   63928
# 2           France   56198
# 3            Spain   50392
# 4        Australia   40107
# 5           Canada   33723
# 6            Italy   33006
# 7          Germany   20477
# 8      Netherlands   18503
# 9          Denmark   16531
# 10         Austria    9141
# 11         Belgium    7392
# 12         Ireland    6706
# 13       Hong Kong    5281
# 14          Greece    5107
# 15     Switzerland    2358
# 16           China      50
# 17    Vatican City       2
# 18          Mexico       2
# 19            Cuba       1
# 20         Vanuatu       1
# 21         Uruguay       1

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_country_counts['Country'], data_country_counts['Count'], color='skyblue')
plt.title('Count by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Data for Property type
property_type_data = [
    ('Apartment', 360447),
    ('House', 96449),
    ('Bed & Breakfast', 11950),
    ('Condominium', 11365),
    ('Townhouse', 6837),
    ('Loft', 6014),
    ('Other', 3560),
    ('Villa', 3124),
    ('Guesthouse', 1848),
    ('Bungalow', 1322),
    ('Dorm', 1149),
    ('Cabin', 989),
    ('Boat', 938),
    ('Chalet', 667),
    ('Guest suite', 653),
    ('Boutique hotel', 529),
    ('Hostel', 468),
    ('Serviced apartment', 450),
    ('Camper/RV', 417),
    ('Timeshare', 264),
    ('Vacation home', 208),
    ('In-law', 182),
    ('Tent', 116),
    ('Treehouse', 71),
    ('Castle', 64),
    ('Earth House', 46),
    ('Yurt', 33),
    ('Hut', 30),
    ('Tipi', 19),
    ('Casa particular', 16),
    ('Nature lodge', 15),
    ('Cave', 12),
    ('Train', 8),
    ('Igloo', 6),
    ('Lighthouse', 6),
    ('Island', 6),
    ('Entire Floor', 5),
    ('Ryokan (Japan)', 2),
    ('Heritage hotel (India)', 1),
    ('Van', 1),
    ('Pension (Korea)', 1),
    ('Parking Space', 1),
    ('Plane', 1)
]

# Create DataFrame
property_type_df = pd.DataFrame(property_type_data, columns=['Property type', 'Count'])

print(property_type_df)

plt.figure(figsize=(10, 6))
plt.bar(property_type_df['Property type'], property_type_df['Count'], color='skyblue')
plt.title('Count by Property type')
plt.xlabel('Property type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  

plt.tight_layout()
plt.show()
# Out:
#              Property type   Count
# 0                Apartment  360447
# 1                    House   96449
# 2          Bed & Breakfast   11950
# 3              Condominium   11365
# 4                Townhouse    6837
# 5                     Loft    6014
# 6                    Other    3560
# 7                    Villa    3124
# 8               Guesthouse    1848
# 9                 Bungalow    1322
# 10                    Dorm    1149
# 11                   Cabin     989
# 12                    Boat     938
# 13                  Chalet     667
# 14             Guest suite     653
# 15          Boutique hotel     529
# 16                  Hostel     468
# 17      Serviced apartment     450
# 18               Camper/RV     417
# 19               Timeshare     264
# 20           Vacation home     208
# 21                  In-law     182
# 22                    Tent     116
# 23               Treehouse      71
# 24                  Castle      64
# 25             Earth House      46
# ...

# %%
# Data
data_room_type = {
    'Room type': ['Entire home/apt', 'Private room', 'Shared room'],
    'Count': [323351, 178103, 8836]
}

# Create DataFrame
df_room_type = pd.DataFrame(data_room_type)

# Display DataFrame
print(df_room_type)
# Out:
#          Room type   Count
# 0  Entire home/apt  323351
# 1     Private room  178103
# 2      Shared room    8836

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_room_type['Room type'], data_room_type['Count'], color='skyblue')
plt.title('Count by data_room_type')
plt.xlabel('Room type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Data
data_accommodates = {
    'Accommodates': [2, 4, 3, 1, 6, 5, 8, 7, 10, 9, 12, 16, 11, 14, 13, 15, 20, 17, 18],
    'Count': [218402, 104514, 48749, 44043, 38662, 24960, 12578, 7040, 4497, 2072, 1888, 1238, 598, 569, 254, 223, 1, 1, 1]
}

# Create DataFrame
df_accommodates = pd.DataFrame(data_accommodates)

# Display DataFrame
print(df_accommodates)
# Out:
#     Accommodates   Count
# 0              2  218402
# 1              4  104514
# 2              3   48749
# 3              1   44043
# 4              6   38662
# 5              5   24960
# 6              8   12578
# 7              7    7040
# 8             10    4497
# 9              9    2072
# 10            12    1888
# 11            16    1238
# 12            11     598
# 13            14     569
# 14            13     254
# 15            15     223
# 16            20       1
# 17            17       1
# 18            18       1

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_accommodates['Accommodates'], data_accommodates['Count'], color='skyblue')
plt.title('Count by Accommodates')
plt.xlabel('Accommodates')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Data
data_bathrooms = {
    'Bathrooms': [1.0, 2.0, 1.5, 2.5, 3.0, 0.5, 3.5, 4.0, 0.0, 5.0, 4.5, 6.0, 8.0, 5.5, 7.0, 6.5, 7.5, 100.0, 9.5, 15.0],
    'Count': [393690, 60371, 28386, 8954, 8542, 2927, 2089, 2017, 1356, 633, 470, 284, 243, 128, 110, 63, 23, 2, 1, 1]
}

# Create DataFrame
df_bathrooms = pd.DataFrame(data_bathrooms)

# Display DataFrame
print(df_bathrooms)
# Out:
#     Bathrooms   Count
# 0         1.0  393690
# 1         2.0   60371
# 2         1.5   28386
# 3         2.5    8954
# 4         3.0    8542
# 5         0.5    2927
# 6         3.5    2089
# 7         4.0    2017
# 8         0.0    1356
# 9         5.0     633
# 10        4.5     470
# 11        6.0     284
# 12        8.0     243
# 13        5.5     128
# 14        7.0     110
# 15        6.5      63
# 16        7.5      23
# 17      100.0       2
# 18        9.5       1
# 19       15.0       1

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_bathrooms['Bathrooms'], data_bathrooms['Count'], color='skyblue')
plt.title('Count by Bathrooms')
plt.xlabel('Bathrooms')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Data
data_bedrooms = {
    'Bedrooms': [1, 2, 3, 0, 4, 5, 6, 7, 8, 10, 9, 11, 15],
    'Count': [331784, 94433, 36431, 30568, 12559, 3095, 909, 236, 114, 108, 49, 3, 1]
}

# Create DataFrame
df_bedrooms = pd.DataFrame(data_bedrooms)

# Display DataFrame
print(df_bedrooms)
# Out:
#     Bedrooms   Count
# 0          1  331784
# 1          2   94433
# 2          3   36431
# 3          0   30568
# 4          4   12559
# 5          5    3095
# 6          6     909
# 7          7     236
# 8          8     114
# 9         10     108
# 10         9      49
# 11        11       3
# 12        15       1

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_bedrooms['Bedrooms'], data_bedrooms['Count'], color='skyblue')
plt.title('Count by Bedrooms')
plt.xlabel('Bedrooms   ')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Data
data_price_range = {
    'Price_Range': ['1-100', '101-200', '201-300', '301-400', '401-500', '501-600', '601-700', '701-800', '801-900', '901-999'],
    'Count': [300381, 130275, 35169, 14706, 9881, 5661, 4666, 4106, 2986, 2319]
}

# Create DataFrame
df_price_range = pd.DataFrame(data_price_range)

# Display DataFrame
print(df_price_range)
# Out:
#   Price_Range   Count
# 0       1-100  300381
# 1     101-200  130275
# 2     201-300   35169
# 3     301-400   14706
# 4     401-500    9881
# 5     501-600    5661
# 6     601-700    4666
# 7     701-800    4106
# 8     801-900    2986
# 9     901-999    2319

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_price_range['Price_Range'], data_price_range['Count'], color='skyblue')
plt.title('Count by Price_Range')
plt.xlabel('Price_Range')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
